# %% [markdown]
# #  MAT120 Lab - Assignment 1
# *   Name: Polok Poddar
# *   ID: 21301644
# *  Section: 05
#
#
#
#
# Copy this colab file, write your name and ID and Submit as a attachment file in the assignment section. Use your BracU g-suit. Run all the code blocks before submission. Be careful of deadline.

# %% [markdown]
# Find the darivative of flowing fuctions,  evaluatae all these fuctions at $x=0$ and $x=2$.  Then plot
# 1. $y=9 x^3-7 x^2+3 x+10$ in the interval $[-50,60]$
# 2. $y=\ln x[6,100]$
# 3. $y=\sin x[20,60]$
# 4. $y=\cos x[-50,60]$
# 5. $y=\tan x[-50,60]$
#
# NB:  You can mane more than one code block for each function. However use appropiate text block and comment to explane your codes.

# %%
#y=9x3−7x2+3x+10  in the interval  [−50,60]
from sympy import*
import numpy as np
import matplotlib.pyplot as pt
x=symbols("x")
y=9*x**3 - 7*x**2 + 3*x + 10
dev_y=diff(y,x)
eq_1=y.subs(x,0)
eq_2=y.subs(x,2)
#Plot the function
lst_x=[]
lst_y=[]
for i in range(-50,60):
    lst_x.append(i)
    m=y.subs(x,i)
    lst_y.append(m)

print("Darivative of flowing fuctions:",dev_y)
print("y(0):",eq_1)
print("y(2):",eq_2)
pt.title("y=9*x**3 - 7*x**2 + 3*x + 10")
pt.plot(lst_x,lst_y)
pt.show()
# Out:
# Darivative of flowing fuctions: 27*x**2 - 14*x + 3
# y(0): 10
# y(2): 60

# %%
#y=lnx[6,100]
from sympy import*
import numpy as np
import matplotlib.pyplot as pt
x=symbols("x")
y=ln(x)
dev_y=diff(y,x)
eq_1=y.subs(x,0)
eq_2=y.subs(x,2)
#Plot the function
lst_x=[]
lst_y=[]
for i in range(6,100):
    lst_x.append(i)
    m=y.subs(x,i)
    lst_y.append(m)

print("Darivative of flowing fuctions:",dev_y)
print("y(0):",eq_1)
print("y(2):",eq_2)
pt.title("y=ln(x)")
pt.plot(lst_x,lst_y)
pt.show()
# Out:
# Darivative of flowing fuctions: 1/x
# y(0): zoo
# y(2): log(2)

# %%
#y=sinx[20,60]
from sympy import*
import numpy as np
import matplotlib.pyplot as pt
x=symbols("x")
y=sin(x)
dev_y=diff(y,x)
eq_1=y.subs(x,0)
eq_2=y.subs(x,2)
#Plot the function
lst_x=[]
lst_y=[]
for i in range(20,60):
    lst_x.append(i)
    m=y.subs(x,i)
    lst_y.append(m)

print("Darivative of flowing fuctions:",dev_y)
print("y(0):",eq_1)
print("y(2):",eq_2)
pt.title("y=sin(x)")
pt.plot(lst_x,lst_y)
pt.show()
# Out:
# Darivative of flowing fuctions: cos(x)
# y(0): 0
# y(2): sin(2)

# %%
#y=cosx[−50,60]
from sympy import*
import numpy as np
import matplotlib.pyplot as pt
x=symbols("x")
y=cos(x)
dev_y=diff(y,x)
eq_1=y.subs(x,0)
eq_2=y.subs(x,2)
#Plot the function
lst_x=[]
lst_y=[]
for i in range(-50,60):
    lst_x.append(i)
    m=y.subs(x,i)
    lst_y.append(m)

print("Darivative of flowing fuctions:",dev_y)
print("y(0):",eq_1)
print("y(2):",eq_2)
pt.title("y=cos(x)")
pt.plot(lst_x,lst_y)
pt.show()
# Out:
# Darivative of flowing fuctions: -sin(x)
# y(0): 1
# y(2): cos(2)

# %%
#y=tanx[−50,60]

from sympy import*
import numpy as np
import matplotlib.pyplot as pt
x=symbols("x")
y=tan(x)
dev_y=diff(y,x)
eq_1=y.subs(x,0)
eq_2=y.subs(x,2)
#Plot the function
lst_x=[]
lst_y=[]
for i in range(-50,60):
    lst_x.append(i)
    m=y.subs(x,i)
    lst_y.append(m)

print("Darivative of flowing fuctions:",dev_y)
print("y(0):",eq_1)
print("y(2):",eq_2)
pt.title("y=tan(x)")
pt.plot(lst_x,lst_y)
pt.show()
# Out:
# Darivative of flowing fuctions: tan(x)**2 + 1
# y(0): 0
# y(2): tan(2)

# %% [markdown]
# To learn how to evaluate limit check out Sympy documentation: https://docs.sympy.org/latest/tutorials/intro-tutorial/calculus.html#limits
#
#
# Evaluate following limits:
#
# 1.  $ \lim_{x \to \pi} \sin(x/2+ \sin(x))$
# 2.   $ \lim_{x \to 0^+} \frac{2e^{1/x}}{e^{1/x}+1} $
# 3. $ \lim_{x \to 0^-} \frac{2e^{1/x}}{e^{1/x}+1} $
# 4. $ \lim_{x \to \infty} \frac{\cos(x)-1}{x} $

# %% [markdown]
#  $ \lim_{x \to \pi} \sin(x/2+ \sin(x))$

# %%
from sympy import*
x=symbols("x")
y=sin(x/2+sin(x))
limit=limit(y,x,pi)
print("Ans is: ",limit)
# Out:
# Ans is:  1

# %% [markdown]
# $ \lim_{x \to 0^+} \frac{2e^{1/x}}{e^{1/x}+1} $

# %%
from sympy import*
x=symbols("x")
y=2*exp(1/x)/(exp(1/x)+1)
limit=limit(y,x,0,dir="+")
print("Ans is: ",limit)
# Out:
# Ans is:  2

# %% [markdown]
# $ \lim_{x \to 0^-} \frac{2e^{1/x}}{e^{1/x}+1} $

# %%
from sympy import*
x=symbols("x")
y=2*exp(1/x)/(exp(1/x)+1)
limit=limit(y,x,0,dir="-")
print("Ans is: ",limit)
# Out:
# Ans is:  0

# %% [markdown]
# $ \lim_{x \to \infty} \frac{\cos(x)-1}{x} $

# %%
from sympy import*
x=symbols("x")
y=(cos(x)-1)/x
limit=limit(y,x,oo)
print("Ans is: ",limit)
# Out:
# Ans is:  0
